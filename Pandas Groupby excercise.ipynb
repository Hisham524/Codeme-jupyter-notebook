# %%
import pandas as pd

# %%
df=pd.read_csv("survey_results_public.csv")
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df[(df['Age']>35)&(df['ConvertedComp']<2000000)&(df['EdLevel']=='Master’s degree (MA, MS, M.Eng., MBA, etc.)')].loc[:][['Age','ConvertedComp','EdLevel']]
# Out:
#         Age  ConvertedComp                                      EdLevel
# 19     38.0        41244.0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 37     44.0        51312.0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 44     62.0       175000.0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 69     42.0        75000.0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 108    41.0        46368.0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...     ...            ...                                          ...
# 88249  40.0        72912.0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88282  43.0       120000.0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88292  36.0        36864.0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88297  37.0        57287.0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88328  37.0        68745.0  Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
# [3785 rows x 3 columns]

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.head
# Out:
# <bound method NDFrame.head of        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
country_group=df.groupby(by=["Country"])

# %%
country_group.get_group
# Out:
# <bound method BaseGroupBy.get_group of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000021736928710>>

# %%
country_group["Gender"].value_counts(normalize=True).loc[["Bangladesh", "Bhutan", "India", "Maldives","Sri Lanka","Pakistan","Afghanistan","Albania"]]
# Out:
# Country      Gender
# Bangladesh   Man                                                            0.932971
#              Woman                                                          0.038043
#              Woman;Man                                                      0.018116
#              Woman;Non-binary, genderqueer, or gender non-conforming        0.005435
#              Man;Non-binary, genderqueer, or gender non-conforming          0.001812
#              Non-binary, genderqueer, or gender non-conforming              0.001812
#              Woman;Man;Non-binary, genderqueer, or gender non-conforming    0.001812
# Bhutan       Man                                                            1.000000
# India        Man                                                            0.924846
#              Woman                                                          0.067568
#              Woman;Man                                                      0.003082
# ...

# %% [markdown]
# ### 1. In each type of developers what is the sum of salary,max salary,min salary and average salary?

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
dev_group=df.groupby(by=["DevType"])

# %%
dev_group.get_group
# Out:
# <bound method BaseGroupBy.get_group of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000002174EBFBB30>>

# %%
dev_group['ConvertedComp'].agg(['mean','median','max','min'])
# Out:
#                                                              mean   median  \
# DevType
# Academic researcher                                 101301.672000  48000.0
# Academic researcher;Data or business analyst        108599.142857  95000.0
# Academic researcher;Data or business analyst;Da...   69967.720000  64992.0
# Academic researcher;Data or business analyst;Da...            NaN      NaN
# Academic researcher;Data or business analyst;Da...            NaN      NaN
# ...                                                           ...      ...
# Senior executive/VP;Student                                   NaN      NaN
# Senior executive/VP;System administrator                      NaN      NaN
# Student                                              37100.066667  12940.5
# Student;System administrator                         54995.000000  16020.0
# System administrator                                104800.538961  45830.0
#
# ...

# %% [markdown]
# ### 2 In each EduLevel what is the average salary, and the average salary between Bachelors degree and masters degree is how much deviated ?

# %%
edulv=df.groupby(by='EdLevel')

# %%
edulv.get_group
# Out:
# <bound method BaseGroupBy.get_group of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000021742FDFAD0>>

# %%
edulv['ConvertedComp'].agg(['median']).reset_index()
# Out:
#                                              EdLevel   median
# 0                                   Associate degree  56092.5
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)  60000.0
# 2             I never completed any formal education  53562.0
# 3        Master’s degree (MA, MS, M.Eng., MBA, etc.)  57744.0
# 4          Other doctoral degree (Ph.D, Ed.D., etc.)  81960.0
# 5                          Primary/elementary school  34368.0
# 6                 Professional degree (JD, MD, etc.)  32998.0
# 7  Secondary school (e.g. American high school, G...  37128.0
# 8  Some college/university study without earning ...  52476.0

# %%
edulv['ConvertedComp'].agg(['median'])
# Out:
#                                                      median
# EdLevel
# Associate degree                                    56092.5
# Bachelor’s degree (BA, BS, B.Eng., etc.)            60000.0
# I never completed any formal education              53562.0
# Master’s degree (MA, MS, M.Eng., MBA, etc.)         57744.0
# Other doctoral degree (Ph.D, Ed.D., etc.)           81960.0
# Primary/elementary school                           34368.0
# Professional degree (JD, MD, etc.)                  32998.0
# Secondary school (e.g. American high school, Ge...  37128.0
# Some college/university study without earning a...  52476.0

# %% [markdown]
# ### 3 What is the median income of each developers with different job satisfaction level?

# %%
dev_group=df.groupby(by=['DevType','JobSat'])

# %%
dev_group.get_group
# Out:
# <bound method BaseGroupBy.get_group of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000002174E74F950>>

# %%
dev_group['ConvertedComp'].agg(['median']).reset_index()
# Out:
#                     DevType                              JobSat   median
# 0       Academic researcher  Neither satisfied nor dissatisfied  41244.0
# 1       Academic researcher               Slightly dissatisfied  43992.0
# 2       Academic researcher                  Slightly satisfied  50858.0
# 3       Academic researcher                   Very dissatisfied  32622.0
# 4       Academic researcher                      Very satisfied  57287.0
# ...                     ...                                 ...      ...
# 16688  System administrator  Neither satisfied nor dissatisfied  43608.0
# 16689  System administrator               Slightly dissatisfied  33961.0
# 16690  System administrator                  Slightly satisfied  42624.0
# 16691  System administrator                   Very dissatisfied  33047.0
# 16692  System administrator                      Very satisfied  59737.5
#
# [16693 rows x 3 columns]

# %% [markdown]
# ### 4 Which databse is the highly worked with database in India and Japan?

# %%
country_group=df.groupby(by='Country')

# %%
country_group.get_group
# Out:
# <bound method BaseGroupBy.get_group of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000002174ED31D60>>

# %%
country_group['DatabaseWorkedWith'].value_counts().loc[["India","Japan"]]
# Out:
# Country  DatabaseWorkedWith
# India    MySQL                            826
#          Microsoft SQL Server             332
#          MySQL;Oracle                     271
#          MySQL;SQLite                     271
#          MongoDB;MySQL                    228
#                                          ...
# Japan    MySQL;Oracle;SQLite                1
#          MySQL;PostgreSQL;Other(s):         1
#          MySQL;PostgreSQL;Redis;SQLite      1
#          Oracle;Other(s):                   1
#          Oracle;SQLite                      1
# Name: count, Length: 1247, dtype: int64

# %% [markdown]
# ### 5 in Which language is most of the Indians want to work in the coming years?

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
country_group["LanguageDesireNextYear"].value_counts().loc["India"]
# Out:
# LanguageDesireNextYear
# Python                            209
# Java                               98
# HTML/CSS;JavaScript;TypeScript     83
# HTML/CSS;JavaScript;PHP;SQL        76
# HTML/CSS;JavaScript                74
#                                  ...
# Swift;TypeScript;Other(s):          1
# Swift;TypeScript;WebAssembly        1
# Swift;WebAssembly                   1
# Swift;WebAssembly;Other(s):         1
# TypeScript;Other(s):                1
# Name: count, Length: 4183, dtype: int64

# %% [markdown]
# ### 6 Is the most desired webframework in India and US is different??

# %%
country_group["WebFrameWorkedWith"].value_counts().loc[["India","United States"]]
# Out:
# Country        WebFrameWorkedWith
# India          jQuery                                                   487
#                Spring                                                   328
#                ASP.NET;jQuery                                           287
#                ASP.NET                                                  251
#                Angular/Angular.js                                       218
#                                                                        ...
# United States  jQuery;Laravel;React.js;Spring                             1
#                jQuery;React.js;Ruby on Rails;Spring;Other(s):             1
#                jQuery;React.js;Ruby on Rails;Spring;Vue.js;Other(s):      1
#                jQuery;React.js;Ruby on Rails;Vue.js;Other(s):             1
#                jQuery;Ruby on Rails;Spring;Other(s):                      1
# Name: count, Length: 1869, dtype: int64

# %% [markdown]
#  ### 7 Which operating system is the most used one in Germany and France?

# %%
country_group["OpSys"].value_counts().loc[["Germany","France"]]
# Out:
# Country  OpSys
# Germany  Windows        2612
#          Linux-based    1734
#          MacOS          1465
#          BSD               7
# France   Windows         977
#          Linux-based     908
#          MacOS           484
# Name: count, dtype: int64

# %% [markdown]
# ### 8 What is the average salary between 20 to 30 years old developers in India?

# %%
fil=df[df['Age'].between(20,30)].loc[:,['ConvertedComp','Age','Country']]

# %%
fil
# Out:
#        ConvertedComp   Age         Country
# 2             8820.0  28.0        Thailand
# 3            61000.0  22.0   United States
# 4                NaN  30.0         Ukraine
# 5           366420.0  28.0          Canada
# 7                NaN  24.0           India
# ...              ...   ...             ...
# 88854            NaN  23.0  United Kingdom
# 88864            NaN  24.0           India
# 88866            NaN  30.0       Australia
# 88871            NaN  21.0           Italy
# 88872            NaN  25.0  Czech Republic
#
# [42656 rows x 3 columns]

# %%
groped=fil.groupby(by=['Country'])

# %%
groped['ConvertedComp'].median().loc['India']
# Out:
# 8676.0

# %% [markdown]
# ### 9 Findout the developers whose age is not equal to 30?(use BITWISE NOT method

# %%
df[(df['Age']!=30)].loc[:][['Age','Country']]
# Out:
#         Age                 Country
# 0      14.0          United Kingdom
# 1      19.0  Bosnia and Herzegovina
# 2      28.0                Thailand
# 3      22.0           United States
# 5      28.0                  Canada
# ...     ...                     ...
# 88878   NaN                  Canada
# 88879   NaN                     NaN
# 88880   NaN                     NaN
# 88881   NaN                     NaN
# 88882  18.0                   Spain
#
# [84833 rows x 2 columns]

# %%
df[~(df['Age']==30)][['Age','Country']]
# Out:
#         Age                 Country
# 0      14.0          United Kingdom
# 1      19.0  Bosnia and Herzegovina
# 2      28.0                Thailand
# 3      22.0           United States
# 5      28.0                  Canada
# ...     ...                     ...
# 88878   NaN                  Canada
# 88879   NaN                     NaN
# 88880   NaN                     NaN
# 88881   NaN                     NaN
# 88882  18.0                   Spain
#
# [84833 rows x 2 columns]

# %% [markdown]
# ### 10 Findout the developers whose salary between 20000 to 25000 or their age is 25 and gender is Woman?

# %%
df[((df["ConvertedComp"]>20000)&(df["ConvertedComp"]<25000))|((df["Gender"]=="Women")&(df["Age"]==25))].loc[:,["DevType","Gender","ConvertedComp"]]
# Out:
#                                                  DevType Gender  ConvertedComp
# 17                              Data or business analyst    Man        21996.0
# 35                             Developer, mobile;Student    Man        20628.0
# 42     Developer, front-end;Developer, game or graphi...    Man        20623.0
# 119         Data or business analyst;Developer, back-end    Man        21612.0
# 154    Engineer, data;Engineer, site reliability;Syst...    Man        24612.0
# ...                                                  ...    ...            ...
# 88144  Developer, back-end;Developer, desktop or ente...    Man        24468.0
# 88180  Developer, back-end;Developer, front-end;Devel...    Man        23376.0
# 88196  Developer, embedded applications or devices;De...    Man        23517.0
# 88256                               Developer, front-end    Man        23832.0
# 88330  Developer, back-end;Developer, desktop or ente...    Man        22915.0
#
# [2293 rows x 3 columns]
